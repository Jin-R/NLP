# %% [markdown]
# # Install

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 9.2MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95

# %% [markdown]
# # Evn

# %%
import os
import random
import shutil
import json
import zipfile
import math
import copy
import collections
import re

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sentencepiece as spm
import tensorflow as tf
import tensorflow.keras.backend as KK

from tqdm.notebook import tqdm

# %%
# random seed initialize
random_seed = 1234
random.seed(random_seed)
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# %%
# !nvidia-smi
# Out:
# Fri Feb  5 02:32:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8    10W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# data dir
data_dir = '/content/drive/MyDrive/data'
os.listdir(data_dir)
# Out:
# ['ko_32000.model', 'ko_32000.vocab', 'kowiki', 'nsmc', 'quora', 'songys']

# %%
# songys chatbot dir
songys_dir = os.path.join(data_dir, 'songys')
if not os.path.exists(songys_dir):
    os.makedirs(songys_dir)
os.listdir(songys_dir)
# Out:
# ['ChatbotData.csv', 'lstm.csv', 'lstm.hdf5']

# %% [markdown]
# # Attention

# %%
# 입력 문장
sentences = [
    ['나는 오늘 기분이 좋아', '네가 좋으니 나도 좋아'],
    ['나는 오늘 행복해', '나도 행복하다'],
]

# %%
# 각 문장을 띄어쓰기 단위로 분할
words = []
for pair in sentences:
    for sentence in pair:
        words.extend(sentence.split())

# 중복 단어 제거
words = list(dict.fromkeys(words))

# 각 단어별 고유한 번호 부여
word_to_id = {'[PAD]': 0, '[UNK]': 1, '[BOS]': 2, '[EOS]': 3}
for word in words:
    word_to_id[word] = len(word_to_id)

# 각 숫자별 단어 부여
id_to_word = {_id:word for word, _id in word_to_id.items()}

word_to_id, id_to_word
# Out:
# ({'[BOS]': 2,
#   '[EOS]': 3,
#   '[PAD]': 0,
#   '[UNK]': 1,
#   '기분이': 6,
#   '나는': 4,
#   '나도': 10,
#   '네가': 8,
#   '오늘': 5,
#   '좋아': 7,
#   '좋으니': 9,
#   '행복하다': 12,
#   '행복해': 11},
#  {0: '[PAD]',
#   1: '[UNK]',
#   2: '[BOS]',
#   3: '[EOS]',
#   4: '나는',
#   5: '오늘',
#   6: '기분이',
#   7: '좋아',
#   8: '네가',
#   9: '좋으니',
#   10: '나도',
#   11: '행복해',
#   12: '행복하다'})

# %%
# Question과 Answer를 숫자료
question_list, answer_list = [], []

for pair in sentences:
    question_list.append([word_to_id[word] for word in pair[0].split()])
    answer_list.append([word_to_id[word] for word in pair[1].split()])

# 학습용 입력 데이터 생성
train_enc_inputs, train_dec_inputs, train_labels = [], [], []

for question, answer in zip(question_list, answer_list):
    train_enc_inputs.append(question)
    train_dec_inputs.append([word_to_id['[BOS]']] + answer)
    train_labels.append(answer + [word_to_id['[EOS]']])

# Encoder 입력의 길이를 모두 동일하게 변경 (최대길이 4)
for row in train_enc_inputs:
    row += [0] * (4 - len(row))

# Decoder 입력의 길이를 모두 동일하게 변경 (최대길이 5)
for row in train_dec_inputs:
    row += [0] * (5 - len(row))

# 정답의 길이를 모두 동일하게 변경 (최대길이 5)
for row in train_labels:
    row += [0] * (5 - len(row))

# numpy array로 변환
train_enc_inputs = np.array(train_enc_inputs)
train_dec_inputs = np.array(train_dec_inputs)
train_labels = np.array(train_labels)

train_enc_inputs, train_dec_inputs, train_labels
# Out:
# (array([[ 4,  5,  6,  7],
#         [ 4,  5, 11,  0]]), array([[ 2,  8,  9, 10,  7],
#         [ 2, 10, 12,  0,  0]]), array([[ 8,  9, 10,  7,  3],
#         [10, 12,  3,  0,  0]]))

# %%
# random embed weight
embed_weight = np.random.randint(-9, 9, (len(id_to_word), 5)) / 10

# embedding 생성
embedding = tf.keras.layers.Embedding(len(id_to_word), 5, weights=[embed_weight])

# word embedding
hidden_enc = embedding(train_enc_inputs)  # (bs, n_enc_seq, 5)
hidden_dec = embedding(train_dec_inputs)  # (bs, n_dec_seq, 5)
hidden_enc, hidden_dec
# Out:
# (<tf.Tensor: shape=(2, 4, 5), dtype=float32, numpy=
#  array([[[ 0.2, -0.9,  0. ,  0.2,  0.7],
#          [-0.6, -0.7,  0.3, -0.8,  0.2],
#          [ 0.2,  0.8,  0.5, -0.2,  0.1],
#          [ 0.2,  0.5,  0.8,  0.4, -0.9]],
#
#         [[ 0.2, -0.9,  0. ,  0.2,  0.7],
#          [-0.6, -0.7,  0.3, -0.8,  0.2],
#          [-0.4,  0.4, -0.3, -0.2, -0.5],
#          [ 0.6, -0.3,  0.3,  0.6,  0.8]]], dtype=float32)>,
#  <tf.Tensor: shape=(2, 5, 5), dtype=float32, numpy=
#  array([[[ 0.7,  0. ,  0.6,  0.7,  0.3],
#          [ 0.3, -0.4,  0.8, -0.4,  0.4],
#          [ 0.7,  0. , -0.1,  0.3, -0.3],
#          [ 0.3,  0.6,  0.8,  0.5, -0.7],
#          [ 0.2,  0.5,  0.8,  0.4, -0.9]],
#
#         [[ 0.7,  0. ,  0.6,  0.7,  0.3],
#          [ 0.3,  0.6,  0.8,  0.5, -0.7],
#          [-0.6, -0.4,  0.5,  0.6,  0.6],
#          [ 0.6, -0.3,  0.3,  0.6,  0.8],
#          [ 0.6, -0.3,  0.3,  0.6,  0.8]]], dtype=float32)>)

# %%
# Q, K, V 선언
Q = hidden_dec
K = hidden_enc
V = K

# %%
# (bs, n_seq, d_model)
# Q[0][0] & K[0][0]
q_idx, k_idx = 0, 0
q_val = Q[0][q_idx]
k_val = K[0][k_idx]
print(q_val)
print(k_val)
print(np.dot(q_val, np.transpose(k_val)))
print(tf.matmul([q_val], [k_val], transpose_b=True))
print(np.sum(q_val * k_val))
# Out:
# tf.Tensor([0.7 0.  0.6 0.7 0.3], shape=(5,), dtype=float32)
# tf.Tensor([ 0.2 -0.9  0.   0.2  0.7], shape=(5,), dtype=float32)
# 0.49
# tf.Tensor([[0.49]], shape=(1, 1), dtype=float32)
# 0.49

# %%
# Q[0][0] & K[0][1]
q_idx, k_idx = 0, 1
q_val = Q[0][q_idx]
k_val = K[0][k_idx]
print(q_val)
print(k_val)
print(np.dot(q_val, np.transpose(k_val)))
print(tf.matmul([q_val], [k_val], transpose_b=True))
print(np.sum(q_val * k_val))
# Out:
# tf.Tensor([0.7 0.  0.6 0.7 0.3], shape=(5,), dtype=float32)
# tf.Tensor([-0.6 -0.7  0.3 -0.8  0.2], shape=(5,), dtype=float32)
# -0.74
# tf.Tensor([[-0.74]], shape=(1, 1), dtype=float32)
# -0.74

# %%
# Q[0][0] & K[0][2]
q_idx, k_idx = 0, 2
q_val = Q[0][q_idx]
k_val = K[0][k_idx]
print(q_val)
print(k_val)
print(np.dot(q_val, np.transpose(k_val)))
print(tf.matmul([q_val], [k_val], transpose_b=True))
print(np.sum(q_val * k_val))
# Out:
# tf.Tensor([0.7 0.  0.6 0.7 0.3], shape=(5,), dtype=float32)
# tf.Tensor([ 0.2  0.8  0.5 -0.2  0.1], shape=(5,), dtype=float32)
# 0.33
# tf.Tensor([[0.33]], shape=(1, 1), dtype=float32)
# 0.33

# %%
# Q[0][0] & K[0][3]
q_idx, k_idx = 0, 3
q_val = Q[0][q_idx]
k_val = K[0][k_idx]
print(q_val)
print(k_val)
print(np.dot(q_val, np.transpose(k_val)))
print(tf.matmul([q_val], [k_val], transpose_b=True))
print(np.sum(q_val * k_val))
# Out:
# tf.Tensor([0.7 0.  0.6 0.7 0.3], shape=(5,), dtype=float32)
# tf.Tensor([ 0.2  0.5  0.8  0.4 -0.9], shape=(5,), dtype=float32)
# 0.63
# tf.Tensor([[0.63]], shape=(1, 1), dtype=float32)
# 0.63

# %%
# Q[0][0] & K[0][*]
attn_row = []
q_val = Q[0][0]
for k_idx in range(4):
    k_val = K[0][k_idx]
    attn_row.append(tf.matmul([q_val], [k_val], transpose_b=True).numpy()[0][0])
attn_row
# Out:
# [0.49, -0.74, 0.33, 0.63]

# %%
# Q[0][*] & K[0][*]
for q_idx in range(5):
    attn_row = []
    q_val = Q[1][q_idx]
    for k_idx in range(4):
        k_val = K[1][k_idx]
        attn_row.append(tf.matmul([q_val], [k_val], transpose_b=True).numpy()[0][0])
    print(attn_row)
# Out:
# [0.49, -0.74, -0.75, 1.26]
# [-0.87, -0.9, 0.13, -0.01999998]
# [0.78, 0.42999995, -0.49, 0.75]
# [1.0699999, -0.38, -0.97, 1.5400001]
# [1.0699999, -0.38, -0.97, 1.5400001]

# %%
# attention score
attn_score = tf.matmul(Q, K, transpose_b=True).numpy()
attn_score
# Out:
# array([[[ 0.49      , -0.74      ,  0.33      ,  0.63      ],
#         [ 0.62      ,  0.74      ,  0.26      , -0.01999995],
#         [-0.01000001, -0.75000006,  0.        ,  0.45000002],
#         [-0.87      , -0.9       ,  0.77000004,  1.83      ],
#         [-0.96      , -0.73      ,  0.6700001 ,  1.9       ]],
#
#        [[ 0.49      , -0.74      , -0.75      ,  1.26      ],
#         [-0.87      , -0.9       ,  0.13      , -0.01999998],
#         [ 0.78      ,  0.42999995, -0.49      ,  0.75      ],
#         [ 1.0699999 , -0.38      , -0.97      ,  1.5400001 ],
#         [ 1.0699999 , -0.38      , -0.97      ,  1.5400001 ]]],
#       dtype=float32)

# %%
# attention prob
attn_prob = tf.nn.softmax(attn_score, axis=-1).numpy()
attn_prob
# Out:
# array([[[0.30351683, 0.08871571, 0.25863996, 0.34912744],
#         [0.2982879 , 0.3363187 , 0.20810843, 0.15728496],
#         [0.24562553, 0.11719136, 0.24809413, 0.38908905],
#         [0.0454435 , 0.04410044, 0.23426896, 0.6761871 ],
#         [0.0402836 , 0.05070093, 0.20560242, 0.70341307]],
#
#        [[0.26727656, 0.07812295, 0.07734562, 0.5772549 ],
#         [0.14228041, 0.13807541, 0.38675827, 0.3328859 ],
#         [0.33829898, 0.23839524, 0.09500505, 0.32830074],
#         [0.33731437, 0.07912394, 0.04386055, 0.53970116],
#         [0.33731437, 0.07912394, 0.04386055, 0.53970116]]], dtype=float32)

# %%
# prob sum 확인
np.sum(attn_prob, axis=-1)
# Out:
# array([[0.9999999, 1.       , 1.       , 1.       , 1.       ],
#        [1.       , 1.       , 1.       , 1.       , 1.       ]],
#       dtype=float32)

# %%
# attn_prob[0][0][0] & V[0][0]
p_idx, v_idx = 0, 0
p_val = attn_prob[0][0][p_idx]
v_val = V[0][v_idx]
print(p_val)
print(v_val)
attn_out_0_0_0 = p_val * v_val
attn_out_0_0_0
# Out:
# 0.30351683
# tf.Tensor([ 0.2 -0.9  0.   0.2  0.7], shape=(5,), dtype=float32)
# <tf.Tensor: shape=(5,), dtype=float32, numpy=
# array([ 0.06070337, -0.27316514,  0.        ,  0.06070337,  0.21246178],
#       dtype=float32)>

# %%
# attn_prob[0][0][1] & V[0][1]
p_idx, v_idx = 1, 1
p_val = attn_prob[0][0][p_idx]
v_val = V[0][v_idx]
print(p_val)
print(v_val)
attn_out_0_0_1 = p_val * v_val
attn_out_0_0_1
# Out:
# 0.08871571
# tf.Tensor([-0.6 -0.7  0.3 -0.8  0.2], shape=(5,), dtype=float32)
# <tf.Tensor: shape=(5,), dtype=float32, numpy=
# array([-0.05322943, -0.062101  ,  0.02661471, -0.07097257,  0.01774314],
#       dtype=float32)>

# %%
# attn_prob[0][0][2] & V[0][2]
p_idx, v_idx = 2, 2
p_val = attn_prob[0][0][p_idx]
v_val = V[0][v_idx]
print(p_val)
print(v_val)
attn_out_0_0_2 = p_val * v_val
attn_out_0_0_2
# Out:
# 0.25863996
# tf.Tensor([ 0.2  0.8  0.5 -0.2  0.1], shape=(5,), dtype=float32)
# <tf.Tensor: shape=(5,), dtype=float32, numpy=
# array([ 0.05172799,  0.20691197,  0.12931998, -0.05172799,  0.025864  ],
#       dtype=float32)>

# %%
# attn_prob[0][0][3] & V[0][3]
p_idx, v_idx = 3, 3
p_val = attn_prob[0][0][p_idx]
v_val = V[0][v_idx]
print(p_val)
print(v_val)
attn_out_0_0_3 = p_val * v_val
attn_out_0_0_3
# Out:
# 0.34912744
# tf.Tensor([ 0.2  0.5  0.8  0.4 -0.9], shape=(5,), dtype=float32)
# <tf.Tensor: shape=(5,), dtype=float32, numpy=
# array([ 0.06982549,  0.17456372,  0.27930197,  0.13965099, -0.31421468],
#       dtype=float32)>

# %%
# attn_prob[0][0][*] & V[0][*]
attn_out_0_0 = attn_out_0_0_0 + attn_out_0_0_1 + attn_out_0_0_2 + attn_out_0_0_3
print(attn_out_0_0)
# Out:
# tf.Tensor([ 0.12902743  0.04620954  0.43523666  0.0776538  -0.05814576], shape=(5,), dtype=float32)

# %%
# attn_prob[0][0][*] & V[0][*]
attn_row = []
for v_idx in range(4):
    attn_row.append(attn_prov[0][0][v_idx] * V[0][v_idx])
print(attn_row)
print(np.sum(attn_row, axis=0))
# Out:
# [<tf.Tensor: shape=(5,), dtype=float32, numpy=
# array([ 0.06070337, -0.27316514,  0.        ,  0.06070337,  0.21246178],
#       dtype=float32)>, <tf.Tensor: shape=(5,), dtype=float32, numpy=
# array([-0.05322943, -0.062101  ,  0.02661471, -0.07097257,  0.01774314],
#       dtype=float32)>, <tf.Tensor: shape=(5,), dtype=float32, numpy=
# array([ 0.05172799,  0.20691197,  0.12931998, -0.05172799,  0.025864  ],
#       dtype=float32)>, <tf.Tensor: shape=(5,), dtype=float32, numpy=
# array([ 0.06982549,  0.17456372,  0.27930197,  0.13965099, -0.31421468],
#       dtype=float32)>]
# [ 0.12902743  0.04620954  0.43523666  0.0776538  -0.05814576]

# %%
# attn_prov[0][*] & V[0][*]
for q_idx in range(5):
    attn_row = []
    for v_idx in range(4):
        attn_row.append(attn_prov[0][q_idx][v_idx] * V[0][v_idx])
    print(np.sum(attn_row, axis=0))
# Out:
# [ 0.12902743  0.04620954  0.43523666  0.0776538  -0.05814576]
# [-0.06905498 -0.25875294  0.3307778  -0.1881051   0.15531965]
# [ 0.10624693  0.0899229   0.47047573  0.06138881 -0.12999457]
# [ 0.16471966  0.45373926  0.6713143   0.1974294  -0.54451096]
# [ 0.15943927  0.44444257  0.68074197  0.20774074 -0.5741728 ]

# %%
# attn_prob & V
attn_out = tf.matmul(attn_prov, V)
attn_out
# Out:
# <tf.Tensor: shape=(2, 5, 5), dtype=float32, numpy=
# array([[[ 0.12902743,  0.04620954,  0.43523666,  0.07765379,
#          -0.05814578],
#         [-0.06905498, -0.25875294,  0.3307778 , -0.18810509,
#           0.15531965],
#         [ 0.10624693,  0.0899229 ,  0.47047573,  0.06138882,
#          -0.12999459],
#         [ 0.16471964,  0.45373926,  0.6713143 ,  0.1974294 ,
#          -0.54451096],
#         [ 0.15943927,  0.44444263,  0.68074197,  0.20774072,
#          -0.5741728 ]],
#
#        [[ 0.32199624, -0.43747318,  0.17340967,  0.3218408 ,
#           0.6258493 ],
#         [-0.00936093, -0.16986763,  0.02526091,  0.04037564,
#           0.20014095],
#         [ 0.08360107, -0.53183395,  0.1415073 ,  0.05492304,
#           0.4996264 ],
#         [ 0.326265  , -0.50333583,  0.17248936,  0.31921232,
#           0.66177547],
#         [ 0.326265  , -0.50333583,  0.17248936,  0.31921232,
#           0.66177547]]], dtype=float32)>

# %%
class DotProductAttention(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, inputs):
        Q, K, V = inputs
        #####################################
        # attention score (dot-product)
        attn_score = tf.matmul(Q, K, transpose_b=True)
        # attention prov
        attn_prob = tf.nn.softmax(attn_score)
        # weighted sum
        attn_out = tf.matmul(attn_prob, V)
        #####################################
        return attn_out

# %%
attention = DotProductAttention()
attention((Q, K, V))
# Out:
# <tf.Tensor: shape=(2, 5, 5), dtype=float32, numpy=
# array([[[ 0.12902743,  0.04620954,  0.43523666,  0.07765379,
#          -0.05814578],
#         [-0.06905498, -0.25875294,  0.3307778 , -0.18810509,
#           0.15531965],
#         [ 0.10624693,  0.0899229 ,  0.47047573,  0.06138882,
#          -0.12999459],
#         [ 0.16471964,  0.45373926,  0.6713143 ,  0.1974294 ,
#          -0.54451096],
#         [ 0.15943927,  0.44444263,  0.68074197,  0.20774072,
#          -0.5741728 ]],
#
#        [[ 0.32199624, -0.43747318,  0.17340967,  0.3218408 ,
#           0.6258493 ],
#         [-0.00936093, -0.16986763,  0.02526091,  0.04037564,
#           0.20014095],
#         [ 0.08360107, -0.53183395,  0.1415073 ,  0.05492304,
#           0.4996264 ],
#         [ 0.326265  , -0.50333583,  0.17248936,  0.31921232,
#           0.66177547],
#         [ 0.326265  , -0.50333583,  0.17248936,  0.31921232,
#           0.66177547]]], dtype=float32)>

# %% [markdown]
# # 모델링

# %%
# word embedding
hidden_enc = embedding(train_enc_inputs)  # (bs, n_enc_seq, 5)
hidden_dec = embedding(train_dec_inputs)  # (bs, n_dec_seq, 5)
hidden_enc, hidden_dec
# Out:
# (<tf.Tensor: shape=(2, 4, 5), dtype=float32, numpy=
#  array([[[ 0.2, -0.9,  0. ,  0.2,  0.7],
#          [-0.6, -0.7,  0.3, -0.8,  0.2],
#          [ 0.2,  0.8,  0.5, -0.2,  0.1],
#          [ 0.2,  0.5,  0.8,  0.4, -0.9]],
#
#         [[ 0.2, -0.9,  0. ,  0.2,  0.7],
#          [-0.6, -0.7,  0.3, -0.8,  0.2],
#          [-0.4,  0.4, -0.3, -0.2, -0.5],
#          [ 0.6, -0.3,  0.3,  0.6,  0.8]]], dtype=float32)>,
#  <tf.Tensor: shape=(2, 5, 5), dtype=float32, numpy=
#  array([[[ 0.7,  0. ,  0.6,  0.7,  0.3],
#          [ 0.3, -0.4,  0.8, -0.4,  0.4],
#          [ 0.7,  0. , -0.1,  0.3, -0.3],
#          [ 0.3,  0.6,  0.8,  0.5, -0.7],
#          [ 0.2,  0.5,  0.8,  0.4, -0.9]],
#
#         [[ 0.7,  0. ,  0.6,  0.7,  0.3],
#          [ 0.3,  0.6,  0.8,  0.5, -0.7],
#          [-0.6, -0.4,  0.5,  0.6,  0.6],
#          [ 0.6, -0.3,  0.3,  0.6,  0.8],
#          [ 0.6, -0.3,  0.3,  0.6,  0.8]]], dtype=float32)>)

# %%
# encoder lstm
fw_cell = tf.keras.layers.LSTM(units=4, return_state=True, return_sequences=True)
bw_cell = tf.keras.layers.LSTM(units=4, go_backwards=True, return_state=True, return_sequences=True)
lstm_enc = tf.keras.layers.Bidirectional(fw_cell, backward_layer=bw_cell)

hidden_enc, fw_h, fw_c, bw_h, bw_c = lstm_enc(hidden_enc)  # (bs, d_model * 2), (bs, d_model), (bs, d_model), (bs, d_model), (bs, d_model)
hidden_enc.shape, fw_h.shape, fw_c.shape, bw_h.shape, bw_c.shape
# Out:
# (TensorShape([2, 4, 8]),
#  TensorShape([2, 4]),
#  TensorShape([2, 4]),
#  TensorShape([2, 4]),
#  TensorShape([2, 4]))

# %%
# concat hidden & cell
s_h = tf.concat([fw_h, bw_h], axis=-1)  # (bs, d_model * 2)
s_c = tf.concat([fw_c, bw_c], axis=-1)  # (bs, d_model * 2)
s_h.shape, s_c.shape
# Out:
# (TensorShape([2, 8]), TensorShape([2, 8]))

# %%
# decoder LSTM
lstm_dec = tf.keras.layers.LSTM(units=8, return_sequences=True)
hidden_dec = lstm_dec(hidden_dec, initial_state=[s_h, s_c])  # (bs, n_dec_seq, d_model)
hidden_dec.shape
# Out:
# TensorShape([2, 5, 8])

# %%
# attention
attention = DotProductAttention()
attn_out = attention((hidden_dec, hidden_enc, hidden_enc))
attn_out.shape
# Out:
# TensorShape([2, 5, 8])

# %%
# concat output
dec_out = tf.concat([attn_out, hidden_dec], axis=-1)
dec_out.shape
# Out:
# TensorShape([2, 5, 16])

# %%
# 다음단어 예측
dense_out = tf.keras.layers.Dense(units=len(word_to_id), activation=tf.nn.softmax)
outputs = dense_out(dec_out)  # (bs, n_dec_seq, n_vocab)
outputs.shape
# Out:
# TensorShape([2, 5, 13])

# %%
def build_model(n_vocab, d_model, n_enc_seq, n_dec_seq):
    """
    seq2seq 모델
    :param n_vocab: vocabulary 단어 수
    :param d_model: 단어를 의미하는 벡터의 차원 수
    :param n_enc_seq: encoder 문장 길이 (단어 수)
    :param n_dec_seq: decoder 문장 길이 (단어 수)
    """
    inputs_enc = tf.keras.layers.Input((n_enc_seq,))  # (bs, n_enc_seq)
    inputs_dec = tf.keras.layers.Input((n_dec_seq,))  # (bs, n_dec_seq)
    ################################################
    # 입력 단어를 vector로 변환
    embedding = tf.keras.layers.Embedding(n_vocab, d_model)
    hidden_enc = embedding(inputs_enc)  # (bs, n_enc_seq, d_model)
    hidden_dec = embedding(inputs_dec)  # (bs, n_dec_seq, d_model)

    # Encoder LSTM (uni-direction, bi-direction 가능)
    fw_cell = tf.keras.layers.LSTM(units=d_model, return_state=True, return_sequences=True)
    bw_cell = tf.keras.layers.LSTM(units=d_model, go_backwards=True, return_state=True, return_sequences=True)
    lstm_enc = tf.keras.layers.Bidirectional(fw_cell, backward_layer=bw_cell)
    hidden_enc, fw_h, fw_c, bw_h, bw_c = lstm_enc(hidden_enc)  # (bs, n_enc_seq, d_model * 2), (bs, d_model), (bs, d_model), (bs, d_model), (bs, d_model)

    # Concatenate hidden states and cell states
    s_h = tf.concat([fw_h, bw_h], axis=-1)  # (bs, d_model * 2)
    s_c = tf.concat([fw_c, bw_c], axis=-1)  # (bs, d_model * 2)

    # Decoder LSTM (uni-direction만 가능)
    lstm_dec = tf.keras.layers.LSTM(units=d_model * 2, return_sequences=True)
    hidden_dec = lstm_dec(hidden_dec, initial_state=[s_h, s_c])  # (bs, n_dec_seq, d_model)

    # attention
    attention = DotProductAttention()
    attn_out = attention((hidden_dec, hidden_enc, hidden_enc))

    # concat output
    dec_out = tf.concat([attn_out, hidden_dec], axis=-1)
    
    # 다음단어 예측
    dense_out = tf.keras.layers.Dense(units=n_vocab, activation=tf.nn.softmax)
    outputs = dense_out(dec_out)  # (bs, n_dec_seq, n_vocab)
    ################################################
    # 학습할 모델 선언
    model = tf.keras.Model(inputs=(inputs_enc, inputs_dec), outputs=outputs)
    return model

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %% [markdown]
# # Vocabulary & config

# %%
# vocab loading
vocab = spm.SentencePieceProcessor()
vocab.load(os.path.join(data_dir, 'ko_32000.model'))
# Out:
# True

# %%
n_vocab = len(vocab)  # number of vocabulary
n_enc_seq = 32  # number of sequence 1
n_dec_seq = 40  # number of sequence 2
d_model = 256  # dimension of model

# %% [markdown]
# # Loss & Acc

# %%
def lm_loss(y_true, y_pred):
    """
    pad 부분을 제외하고 loss를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 loss 값
    """
    # loss = sparse_entropy = tf.keras.losses.SparseCategoricalCrossentropy()(y_true, y_pred)
    loss = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)(y_true, y_pred)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    loss *= mask
    return loss

# %%
def lm_acc(y_true, y_pred):
    """
    pad 부분을 제외하고 accuracy를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 accuracy 값
    """
    y_true = tf.cast(y_true, tf.float32)
    # print(y_true)
    y_pred_class = tf.cast(tf.argmax(y_pred, axis=-1), tf.float32)
    # print(y_pred_class)
    matches = tf.cast(tf.equal(y_true, y_pred_class), tf.float32)
    # print(matches)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    matches *= mask
    # print(matches)
    # accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(tf.ones_like(matches)), 1)
    accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(mask), 1)
    return accuracy

# %% [markdown]
# # Sample Data Project

# %% [markdown]
# ## Data

# %%
df_train = pd.read_csv(os.path.join(songys_dir, 'ChatbotData.csv'))
df_train

# %%
df_train = df_train.dropna()
df_train

# %%
# 랜덤하게 10개만 확인
df_train = df_train.sample(10)
df_train

# %%
def load_data(df, n_enc_seq, n_dec_seq):
    """
    Quora 학습 데이터 생성
    :param df: data frame
    :param n_enc_seq: number of encoder sequence
    :param n_dec_seq: number of decoder sequence
    :return enc_inputs: encoder input data
    :return dec_inputs: decoder input data
    :return labels: label data
    """
    n_enc_max = n_enc_seq
    n_dec_max = n_dec_seq - 1
    enc_inputs = np.zeros((len(df), n_enc_seq)).astype(np.int32)
    dec_inputs = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    labels = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    index = 0
    for i, row in tqdm(df.iterrows(), total=len(df)):
        # tokens 저장
        print()
        Q = row['Q']
        A = row['A']
        print(Q, '/', A)

        tokens_q = vocab.encode_as_pieces(Q)
        print(len(tokens_q), ':', tokens_q)
        tokens_a = vocab.encode_as_pieces(A)
        print(len(tokens_a), ':', tokens_a)

        tokens_ids_q = vocab.encode_as_ids(Q)[:n_enc_max]
        print(len(tokens_ids_q), ':', tokens_ids_q)
        tokens_ids_a = vocab.encode_as_ids(A)[:n_dec_max]
        print(len(tokens_ids_a), ':', tokens_ids_a)

        tokens_dec_in = [vocab.bos_id()] + tokens_ids_a
        tokens_dec_out = tokens_ids_a + [vocab.eos_id()]

        tokens_ids_q += [0] * (n_enc_seq - len(tokens_ids_q))
        print(len(tokens_ids_q), ':', tokens_ids_q)
        tokens_dec_in += [0] * (n_dec_seq - len(tokens_dec_in))
        print(len(tokens_dec_in), ':', tokens_dec_in)
        tokens_dec_out += [0] * (n_dec_seq - len(tokens_dec_out))
        print(len(tokens_dec_out), ':', tokens_dec_out)

        enc_inputs[index] = tokens_ids_q
        dec_inputs[index] = tokens_dec_in
        labels[index] = tokens_dec_out
        index += 1
    return enc_inputs, dec_inputs, labels

# %%
# train data 생성
train_enc_inputs, train_dec_inputs, train_labels = load_data(df_train, n_enc_seq, n_dec_seq)
train_enc_inputs, train_dec_inputs, train_labels

# %% [markdown]
# ## 학습

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %%
# 모델 loss, optimizer, metric 정의
model.compile(loss=lm_loss, optimizer='adam', metrics=[lm_acc])

# %%
# early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='lm_acc', patience=100)
# save weights callback
save_weights = tf.keras.callbacks.ModelCheckpoint(os.path.join(songys_dir, 'lstm_dot.hdf5'),
                                                  monitor='lm_acc',
                                                  verbose=1,
                                                  save_best_only=True,
                                                  mode="max",
                                                  save_freq="epoch",
                                                  save_weights_only=True)
# csv logger
csv_logger = tf.keras.callbacks.CSVLogger(os.path.join(songys_dir, 'lstm_dot.csv'))

# %%
# 모델 학습
history = model.fit((train_enc_inputs, train_dec_inputs),
                    train_labels,
                    epochs=400,
                    batch_size=256,
                    callbacks=[early_stopping, save_weights, csv_logger])

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['lm_acc'], 'g-', label='acc')
plt.xlabel('Epoch')
plt.legend()

plt.show()

# %% [markdown]
# ## Inference

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# train weight로 초기화
model.load_weights(os.path.join(songys_dir, 'lstm_dot.hdf5'))

# %%
def do_chat(vocab, model, n_enc_seq, n_dec_seq, string):
    """
    seq2seq chat
    :param vocab: vocab
    :param model: model
    :param n_enc_seq: number of enc seqence
    :param n_dec_seq: number of dec seqence
    :param string: inpust string
    """
    # qeustion
    q = vocab.encode_as_pieces(string)
    q_id = [vocab.piece_to_id(p) for p in q][:n_enc_seq]
    q_id += [0] * (n_enc_seq - len(q_id))
    assert len(q_id) == n_enc_seq

    # answer
    a_id = [vocab.bos_id()]
    a_id += [0] * (n_dec_seq - len(a_id))
    assert len(a_id) == n_dec_seq

    # 처음부터 예측
    start_idx = 0

    for _ in range(start_idx, n_dec_seq - 1):
        outputs = model.predict((np.array([q_id]), np.array([a_id])))
        prob = outputs[0][start_idx]
        word_id = np.argmax(prob)
        if word_id == vocab.eos_id():
            break
        a_id[start_idx + 1] = int(word_id)
        start_idx += 1
    predict_id = a_id[1:start_idx + 1]
    predict_str = vocab.decode_ids(predict_id)
    return predict_str

# %%
while True:
    string = input('질문 > ')
    string = string.strip()
    if len(string) == 0:
        break
    predict_str = do_chat(vocab, model, n_enc_seq, n_dec_seq, string)
    print(f'답변 > {predict_str}')

# %% [markdown]
# # All Data Project

# %% [markdown]
# ## Data

# %%
df_train = pd.read_csv(os.path.join(songys_dir, 'ChatbotData.csv'))
print(len(df_train))
df_train = df_train.dropna()
print(len(df_train))
df_train
# Out:
# 11823
# 11823
#                              Q                         A  label
# 0                       12시 땡!                하루가 또 가네요.      0
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.      0
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.      0
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.      0
# 4                      PPL 심하네                눈살이 찌푸려지죠.      0
# ...                        ...                       ...    ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!      2
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.      2
# 11820              흑기사 해주는 짝남.                    설렜겠어요.      2
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.      2
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.      2
#
# [11823 rows x 3 columns]

# %%
def load_data(df, n_enc_seq, n_dec_seq):
    """
    Quora 학습 데이터 생성
    :param df: data frame
    :param n_enc_seq: number of encoder sequence
    :param n_dec_seq: number of decoder sequence
    :return enc_inputs: encoder input data
    :return dec_inputs: decoder input data
    :return labels: label data
    """
    n_enc_max = n_enc_seq
    n_dec_max = n_dec_seq - 1
    enc_inputs = np.zeros((len(df), n_enc_seq)).astype(np.int32)
    dec_inputs = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    labels = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    index = 0
    for i, row in tqdm(df.iterrows(), total=len(df)):
        # tokens 저장
        Q = row['Q']
        A = row['A']

        tokens_q = vocab.encode_as_pieces(Q)
        tokens_a = vocab.encode_as_pieces(A)

        tokens_ids_q = vocab.encode_as_ids(Q)[:n_enc_max]
        tokens_ids_a = vocab.encode_as_ids(A)[:n_dec_max]

        tokens_dec_in = [vocab.bos_id()] + tokens_ids_a
        tokens_dec_out = tokens_ids_a + [vocab.eos_id()]

        tokens_ids_q += [0] * (n_enc_seq - len(tokens_ids_q))
        tokens_dec_in += [0] * (n_dec_seq - len(tokens_dec_in))
        tokens_dec_out += [0] * (n_dec_seq - len(tokens_dec_out))

        enc_inputs[index] = tokens_ids_q
        dec_inputs[index] = tokens_dec_in
        labels[index] = tokens_dec_out
        index += 1
    return enc_inputs, dec_inputs, labels

# %%
# train data 생성
train_enc_inputs, train_dec_inputs, train_labels = load_data(df_train, n_enc_seq, n_dec_seq)
train_enc_inputs, train_dec_inputs, train_labels
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11823.0), HTML(value='')))
# (array([[   89,    56,    10, ...,     0,     0,     0],
#         [   35,    47,  1004, ...,     0,     0,     0],
#         [   38,   819,   362, ...,     0,     0,     0],
#         ...,
#         [ 2886,  9525, 21930, ...,     0,     0,     0],
#         [10736,  8256,  1172, ...,     0,     0,     0],
#         [26128,    70,  1381, ...,     0,     0,     0]], dtype=int32),
#  array([[    2,  2261,    19, ...,     0,     0,     0],
#         [    2,  4594,    61, ...,     0,     0,     0],
#         [    2,  2350,    18, ...,     0,     0,     0],
#         ...,
#         [    2,  1522,     1, ...,     0,     0,     0],
#         [    2,   441, 10316, ...,     0,     0,     0],
#         [    2, 16665,    90, ...,     0,     0,     0]], dtype=int32),
#  array([[ 2261,    19,   375, ...,     0,     0,     0],
#         [ 4594,    61,   929, ...,     0,     0,     0],
#         [ 2350,    18,  9001, ...,     0,     0,     0],
#         ...,
#         [ 1522,     1, 12273, ...,     0,     0,     0],
#         [  441, 10316,   515, ...,     0,     0,     0],
#         [16665,    90,  1381, ...,     0,     0,     0]], dtype=int32))

# %% [markdown]
# ## 학습

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %%
# 모델 loss, optimizer, metric 정의
model.compile(loss=lm_loss, optimizer='adam', metrics=[lm_acc])

# %%
# early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='lm_acc', patience=5)
# save weights callback
save_weights = tf.keras.callbacks.ModelCheckpoint(os.path.join(songys_dir, 'lstm_dot.hdf5'),
                                                  monitor='lm_acc',
                                                  verbose=1,
                                                  save_best_only=True,
                                                  mode="max",
                                                  save_freq="epoch",
                                                  save_weights_only=True)
# csv logger
csv_logger = tf.keras.callbacks.CSVLogger(os.path.join(songys_dir, 'lstm_dot.csv'))

# %%
# 모델 학습
history = model.fit((train_enc_inputs, train_dec_inputs),
                    train_labels,
                    epochs=100,
                    batch_size=256,
                    callbacks=[early_stopping, save_weights, csv_logger])
# Out:
# Epoch 1/100
# 47/47 [==============================] - 42s 818ms/step - loss: 1.8687 - lm_acc: 0.1022
#
# Epoch 00001: lm_acc improved from -inf to 0.11879, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 2/100
# 47/47 [==============================] - 39s 838ms/step - loss: 1.2798 - lm_acc: 0.1707
#
# Epoch 00002: lm_acc improved from 0.11879 to 0.19812, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 3/100
# 47/47 [==============================] - 40s 862ms/step - loss: 1.1448 - lm_acc: 0.2697
#
# Epoch 00003: lm_acc improved from 0.19812 to 0.27794, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 4/100
# 47/47 [==============================] - 40s 861ms/step - loss: 1.0770 - lm_acc: 0.3013
#
# Epoch 00004: lm_acc improved from 0.27794 to 0.31255, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 5/100
# 47/47 [==============================] - 40s 859ms/step - loss: 1.0170 - lm_acc: 0.3401
#
# Epoch 00005: lm_acc improved from 0.31255 to 0.34876, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 6/100
# 47/47 [==============================] - 40s 858ms/step - loss: 0.9571 - lm_acc: 0.3692
#
# Epoch 00006: lm_acc improved from 0.34876 to 0.37268, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 7/100
# 47/47 [==============================] - 40s 857ms/step - loss: 0.9107 - lm_acc: 0.3866
#
# Epoch 00007: lm_acc improved from 0.37268 to 0.39181, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 8/100
# 47/47 [==============================] - 40s 859ms/step - loss: 0.8645 - lm_acc: 0.4033
#
# Epoch 00008: lm_acc improved from 0.39181 to 0.40682, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 9/100
# 47/47 [==============================] - 40s 859ms/step - loss: 0.8255 - lm_acc: 0.4181
#
# Epoch 00009: lm_acc improved from 0.40682 to 0.41971, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 10/100
# 47/47 [==============================] - 41s 861ms/step - loss: 0.7940 - lm_acc: 0.4291
#
# Epoch 00010: lm_acc improved from 0.41971 to 0.43080, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 11/100
# 47/47 [==============================] - 40s 861ms/step - loss: 0.7612 - lm_acc: 0.4424
#
# Epoch 00011: lm_acc improved from 0.43080 to 0.44209, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 12/100
# 47/47 [==============================] - 40s 861ms/step - loss: 0.7314 - lm_acc: 0.4544
#
# Epoch 00012: lm_acc improved from 0.44209 to 0.45542, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 13/100
# 47/47 [==============================] - 41s 865ms/step - loss: 0.7075 - lm_acc: 0.4665
#
# Epoch 00013: lm_acc improved from 0.45542 to 0.46537, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 14/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.6864 - lm_acc: 0.4741
#
# Epoch 00014: lm_acc improved from 0.46537 to 0.47721, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 15/100
# 47/47 [==============================] - 41s 861ms/step - loss: 0.6607 - lm_acc: 0.4888
#
# Epoch 00015: lm_acc improved from 0.47721 to 0.48778, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 16/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.6330 - lm_acc: 0.5030
#
# Epoch 00016: lm_acc improved from 0.48778 to 0.50073, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 17/100
# 47/47 [==============================] - 41s 861ms/step - loss: 0.6128 - lm_acc: 0.5145
#
# Epoch 00017: lm_acc improved from 0.50073 to 0.51401, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 18/100
# 47/47 [==============================] - 41s 861ms/step - loss: 0.5911 - lm_acc: 0.5272
#
# Epoch 00018: lm_acc improved from 0.51401 to 0.52636, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 19/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.5693 - lm_acc: 0.5418
#
# Epoch 00019: lm_acc improved from 0.52636 to 0.53969, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 20/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.5444 - lm_acc: 0.5562
#
# Epoch 00020: lm_acc improved from 0.53969 to 0.55420, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 21/100
# 47/47 [==============================] - 40s 858ms/step - loss: 0.5258 - lm_acc: 0.5685
#
# Epoch 00021: lm_acc improved from 0.55420 to 0.56405, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 22/100
# 47/47 [==============================] - 40s 855ms/step - loss: 0.5087 - lm_acc: 0.5806
#
# Epoch 00022: lm_acc improved from 0.56405 to 0.57598, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 23/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.4924 - lm_acc: 0.5914
#
# Epoch 00023: lm_acc improved from 0.57598 to 0.59096, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 24/100
# 47/47 [==============================] - 40s 861ms/step - loss: 0.4699 - lm_acc: 0.6050
#
# Epoch 00024: lm_acc improved from 0.59096 to 0.60376, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 25/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.4562 - lm_acc: 0.6184
#
# Epoch 00025: lm_acc improved from 0.60376 to 0.61753, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 26/100
# 47/47 [==============================] - 41s 861ms/step - loss: 0.4348 - lm_acc: 0.6338
#
# Epoch 00026: lm_acc improved from 0.61753 to 0.63013, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 27/100
# 47/47 [==============================] - 40s 861ms/step - loss: 0.4173 - lm_acc: 0.6466
#
# Epoch 00027: lm_acc improved from 0.63013 to 0.64149, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 28/100
# 47/47 [==============================] - 41s 865ms/step - loss: 0.4012 - lm_acc: 0.6579
#
# Epoch 00028: lm_acc improved from 0.64149 to 0.65471, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 29/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.3879 - lm_acc: 0.6703
#
# Epoch 00029: lm_acc improved from 0.65471 to 0.66782, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 30/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.3694 - lm_acc: 0.6841
#
# Epoch 00030: lm_acc improved from 0.66782 to 0.68216, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 31/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.3550 - lm_acc: 0.6979
#
# Epoch 00031: lm_acc improved from 0.68216 to 0.69510, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 32/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.3373 - lm_acc: 0.7119
#
# Epoch 00032: lm_acc improved from 0.69510 to 0.70629, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 33/100
# 47/47 [==============================] - 40s 858ms/step - loss: 0.3248 - lm_acc: 0.7197
#
# Epoch 00033: lm_acc improved from 0.70629 to 0.71867, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 34/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.3079 - lm_acc: 0.7348
#
# Epoch 00034: lm_acc improved from 0.71867 to 0.73207, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 35/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.2928 - lm_acc: 0.7476
#
# Epoch 00035: lm_acc improved from 0.73207 to 0.74356, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 36/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.2808 - lm_acc: 0.7593
#
# Epoch 00036: lm_acc improved from 0.74356 to 0.75596, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 37/100
# 47/47 [==============================] - 41s 863ms/step - loss: 0.2654 - lm_acc: 0.7710
#
# Epoch 00037: lm_acc improved from 0.75596 to 0.76720, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 38/100
# 47/47 [==============================] - 41s 866ms/step - loss: 0.2544 - lm_acc: 0.7851
#
# Epoch 00038: lm_acc improved from 0.76720 to 0.77878, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 39/100
# 47/47 [==============================] - 41s 868ms/step - loss: 0.2387 - lm_acc: 0.7966
#
# Epoch 00039: lm_acc improved from 0.77878 to 0.79153, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 40/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.2274 - lm_acc: 0.8084
#
# Epoch 00040: lm_acc improved from 0.79153 to 0.80022, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 41/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.2189 - lm_acc: 0.8157
#
# Epoch 00041: lm_acc improved from 0.80022 to 0.80938, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 42/100
# 47/47 [==============================] - 41s 861ms/step - loss: 0.2087 - lm_acc: 0.8237
#
# Epoch 00042: lm_acc improved from 0.80938 to 0.82110, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 43/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.1971 - lm_acc: 0.8361
#
# Epoch 00043: lm_acc improved from 0.82110 to 0.83227, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 44/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.1851 - lm_acc: 0.8471
#
# Epoch 00044: lm_acc improved from 0.83227 to 0.84163, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 45/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.1774 - lm_acc: 0.8544
#
# Epoch 00045: lm_acc improved from 0.84163 to 0.84968, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 46/100
# 47/47 [==============================] - 41s 865ms/step - loss: 0.1672 - lm_acc: 0.8640
#
# Epoch 00046: lm_acc improved from 0.84968 to 0.86042, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 47/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.1588 - lm_acc: 0.8733
#
# Epoch 00047: lm_acc improved from 0.86042 to 0.86860, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 48/100
# 47/47 [==============================] - 41s 865ms/step - loss: 0.1516 - lm_acc: 0.8787
#
# Epoch 00048: lm_acc improved from 0.86860 to 0.87674, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 49/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.1412 - lm_acc: 0.8894
#
# Epoch 00049: lm_acc improved from 0.87674 to 0.88504, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 50/100
# 47/47 [==============================] - 40s 861ms/step - loss: 0.1325 - lm_acc: 0.8980
#
# Epoch 00050: lm_acc improved from 0.88504 to 0.89416, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 51/100
# 47/47 [==============================] - 41s 863ms/step - loss: 0.1256 - lm_acc: 0.9058
#
# Epoch 00051: lm_acc improved from 0.89416 to 0.90209, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 52/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.1193 - lm_acc: 0.9112
#
# Epoch 00052: lm_acc improved from 0.90209 to 0.90885, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 53/100
# 47/47 [==============================] - 41s 869ms/step - loss: 0.1112 - lm_acc: 0.9192
#
# Epoch 00053: lm_acc improved from 0.90885 to 0.91654, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 54/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.1044 - lm_acc: 0.9262
#
# Epoch 00054: lm_acc improved from 0.91654 to 0.92296, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 55/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.0979 - lm_acc: 0.9321
#
# Epoch 00055: lm_acc improved from 0.92296 to 0.92985, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 56/100
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0920 - lm_acc: 0.9384
#
# Epoch 00056: lm_acc improved from 0.92985 to 0.93602, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 57/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.0850 - lm_acc: 0.9439
#
# Epoch 00057: lm_acc improved from 0.93602 to 0.94055, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 58/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.0815 - lm_acc: 0.9489
#
# Epoch 00058: lm_acc improved from 0.94055 to 0.94617, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 59/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.0760 - lm_acc: 0.9531
#
# Epoch 00059: lm_acc improved from 0.94617 to 0.95088, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 60/100
# 47/47 [==============================] - 40s 859ms/step - loss: 0.0712 - lm_acc: 0.9585
#
# Epoch 00060: lm_acc improved from 0.95088 to 0.95590, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 61/100
# 47/47 [==============================] - 40s 861ms/step - loss: 0.0667 - lm_acc: 0.9617
#
# Epoch 00061: lm_acc improved from 0.95590 to 0.96045, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 62/100
# 47/47 [==============================] - 40s 858ms/step - loss: 0.0622 - lm_acc: 0.9655
#
# Epoch 00062: lm_acc improved from 0.96045 to 0.96454, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 63/100
# 47/47 [==============================] - 40s 859ms/step - loss: 0.0577 - lm_acc: 0.9693
#
# Epoch 00063: lm_acc improved from 0.96454 to 0.96824, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 64/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.0547 - lm_acc: 0.9720
#
# Epoch 00064: lm_acc improved from 0.96824 to 0.97086, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 65/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.0516 - lm_acc: 0.9734
#
# Epoch 00065: lm_acc improved from 0.97086 to 0.97165, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 66/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0489 - lm_acc: 0.9764
#
# Epoch 00066: lm_acc improved from 0.97165 to 0.97479, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 67/100
# 47/47 [==============================] - 40s 862ms/step - loss: 0.0456 - lm_acc: 0.9786
#
# Epoch 00067: lm_acc improved from 0.97479 to 0.97787, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 68/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0415 - lm_acc: 0.9822
#
# Epoch 00068: lm_acc improved from 0.97787 to 0.98091, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 69/100
# 47/47 [==============================] - 40s 856ms/step - loss: 0.0379 - lm_acc: 0.9849
#
# Epoch 00069: lm_acc improved from 0.98091 to 0.98341, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 70/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0365 - lm_acc: 0.9863
#
# Epoch 00070: lm_acc improved from 0.98341 to 0.98535, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 71/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0330 - lm_acc: 0.9885
#
# Epoch 00071: lm_acc improved from 0.98535 to 0.98717, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 72/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0312 - lm_acc: 0.9892
#
# Epoch 00072: lm_acc improved from 0.98717 to 0.98789, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 73/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0310 - lm_acc: 0.9892
#
# Epoch 00073: lm_acc improved from 0.98789 to 0.98857, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 74/100
# 47/47 [==============================] - 41s 863ms/step - loss: 0.0280 - lm_acc: 0.9906
#
# Epoch 00074: lm_acc improved from 0.98857 to 0.99033, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 75/100
# 47/47 [==============================] - 40s 861ms/step - loss: 0.0273 - lm_acc: 0.9913
#
# Epoch 00075: lm_acc improved from 0.99033 to 0.99069, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 76/100
# 47/47 [==============================] - 41s 865ms/step - loss: 0.0254 - lm_acc: 0.9929
#
# Epoch 00076: lm_acc improved from 0.99069 to 0.99189, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 77/100
# 47/47 [==============================] - 41s 863ms/step - loss: 0.0241 - lm_acc: 0.9929
#
# Epoch 00077: lm_acc improved from 0.99189 to 0.99256, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 78/100
# 47/47 [==============================] - 41s 862ms/step - loss: 0.0215 - lm_acc: 0.9951
#
# Epoch 00078: lm_acc improved from 0.99256 to 0.99454, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 79/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.0195 - lm_acc: 0.9958
#
# Epoch 00079: lm_acc improved from 0.99454 to 0.99521, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 80/100
# 47/47 [==============================] - 41s 865ms/step - loss: 0.0187 - lm_acc: 0.9958
#
# Epoch 00080: lm_acc improved from 0.99521 to 0.99534, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 81/100
# 47/47 [==============================] - 40s 861ms/step - loss: 0.0175 - lm_acc: 0.9960
#
# Epoch 00081: lm_acc improved from 0.99534 to 0.99585, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 82/100
# 47/47 [==============================] - 41s 864ms/step - loss: 0.0160 - lm_acc: 0.9970
#
# Epoch 00082: lm_acc improved from 0.99585 to 0.99663, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 83/100
# 47/47 [==============================] - 40s 858ms/step - loss: 0.0150 - lm_acc: 0.9973
#
# Epoch 00083: lm_acc improved from 0.99663 to 0.99685, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 84/100
# 47/47 [==============================] - 40s 852ms/step - loss: 0.0144 - lm_acc: 0.9974
#
# Epoch 00084: lm_acc improved from 0.99685 to 0.99685, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 85/100
# 47/47 [==============================] - 40s 851ms/step - loss: 0.0134 - lm_acc: 0.9975
#
# Epoch 00085: lm_acc improved from 0.99685 to 0.99719, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 86/100
# 47/47 [==============================] - 40s 860ms/step - loss: 0.0122 - lm_acc: 0.9981
#
# Epoch 00086: lm_acc improved from 0.99719 to 0.99774, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 87/100
# 47/47 [==============================] - 40s 850ms/step - loss: 0.0116 - lm_acc: 0.9982
#
# Epoch 00087: lm_acc improved from 0.99774 to 0.99783, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 88/100
# 47/47 [==============================] - 40s 850ms/step - loss: 0.0110 - lm_acc: 0.9985
#
# Epoch 00088: lm_acc improved from 0.99783 to 0.99825, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 89/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.0102 - lm_acc: 0.9984
#
# Epoch 00089: lm_acc improved from 0.99825 to 0.99827, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 90/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0096 - lm_acc: 0.9987
#
# Epoch 00090: lm_acc improved from 0.99827 to 0.99846, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 91/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0089 - lm_acc: 0.9988
#
# Epoch 00091: lm_acc improved from 0.99846 to 0.99850, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 92/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.0086 - lm_acc: 0.9987
#
# Epoch 00092: lm_acc did not improve from 0.99850
# Epoch 93/100
# 47/47 [==============================] - 40s 854ms/step - loss: 0.0082 - lm_acc: 0.9989
#
# Epoch 00093: lm_acc improved from 0.99850 to 0.99861, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 94/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.0077 - lm_acc: 0.9988
#
# Epoch 00094: lm_acc did not improve from 0.99861
# Epoch 95/100
# 47/47 [==============================] - 40s 850ms/step - loss: 0.0073 - lm_acc: 0.9988
#
# Epoch 00095: lm_acc improved from 0.99861 to 0.99877, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 96/100
# 47/47 [==============================] - 40s 848ms/step - loss: 0.0069 - lm_acc: 0.9991
#
# Epoch 00096: lm_acc improved from 0.99877 to 0.99886, saving model to /content/drive/MyDrive/data/songys/lstm_dot.hdf5
# Epoch 97/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0067 - lm_acc: 0.9988
#
# Epoch 00097: lm_acc did not improve from 0.99886
# Epoch 98/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.0063 - lm_acc: 0.9989
#
# Epoch 00098: lm_acc did not improve from 0.99886
# Epoch 99/100
# 47/47 [==============================] - 40s 856ms/step - loss: 0.0065 - lm_acc: 0.9986
#
# Epoch 00099: lm_acc did not improve from 0.99886
# Epoch 100/100
# 47/47 [==============================] - 40s 852ms/step - loss: 0.0065 - lm_acc: 0.9987
#
# Epoch 00100: lm_acc did not improve from 0.99886

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['lm_acc'], 'g-', label='acc')
plt.xlabel('Epoch')
plt.legend()

plt.show()

# %% [markdown]
# ## Inference

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# train weight로 초기화
model.load_weights(os.path.join(songys_dir, 'lstm_dot.hdf5'))

# %%
def do_chat(vocab, model, n_enc_seq, n_dec_seq, string):
    """
    seq2seq chat
    :param vocab: vocab
    :param model: model
    :param n_enc_seq: number of enc seqence
    :param n_dec_seq: number of dec seqence
    :param string: inpust string
    """
    # qeustion
    q = vocab.encode_as_pieces(string)
    q_id = [vocab.piece_to_id(p) for p in q][:n_enc_seq]
    q_id += [0] * (n_enc_seq - len(q_id))
    assert len(q_id) == n_enc_seq

    # answer
    a_id = [vocab.bos_id()]
    a_id += [0] * (n_dec_seq - len(a_id))
    assert len(a_id) == n_dec_seq

    # 처음부터 예측
    start_idx = 0

    for _ in range(start_idx, n_dec_seq - 1):
        outputs = model.predict((np.array([q_id]), np.array([a_id])))
        prob = outputs[0][start_idx]
        word_id = np.argmax(prob)
        if word_id == vocab.eos_id():
            break
        a_id[start_idx + 1] = int(word_id)
        start_idx += 1
    predict_id = a_id[1:start_idx + 1]
    predict_str = vocab.decode_ids(predict_id)
    return predict_str

# %%
while True:
    string = input('질문 > ')
    string = string.strip()
    if len(string) == 0:
        break
    predict_str = do_chat(vocab, model, n_enc_seq, n_dec_seq, string)
    print(f'답변 > {predict_str}')
# Out:
# 질문 > 안녕
# 답변 > 안녕하세요.
# 질문 > 너는 누구야
# 답변 > 자신을 우선순위로 해주세요.
# 질문 > 너 이름이 뭐야
# 답변 > 제가 따라가려면 멀었네요.
# 질문 > 나는 누굴까
# 답변 > 뭐든 좋겠죠.
# 질문 > 지금 뭐햐
# 답변 > 저랑 놀아요.
# 질문 > 잘 하는게 뭐야
# 답변 > 잘 찾아보세요.
# 질문 > 피곤해
# 답변 > 충전하는 시간 그 자체로 소중합니다.
# 질문 > 졸려
# 답변 > 오늘 일찍 주무세요.
# 질문 > 내일은 주말이야
# 답변 > 기분나쁘겠어요.
# 질문 > 나 공부해야 돼
# 답변 > 같이 살고 싶은 사람이 있나봐요.
# 질문 > 나가기 싫어
# 답변 > 혼자도 함께도 잘 지내는 게 좋죠.
# 질문 > 놀고싶어
# 답변 > 저도 궁금하네요.
# 질문 >  나 갈래
# 답변 > 저는 좋아요.
# 질문 > 잘 자
# 답변 > 잘자요.
# 질문 > 다음에 보자
# 답변 > 잘가요.
# 질문 >
