# %% [markdown]
# # Install

# %%
# !pip install sentencepiece
# Out:
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/14/67/e42bd1181472c95c8cda79305df848264f2a7f62740995a46945d9797b67/sentencepiece-0.1.95-cp36-cp36m-manylinux2014_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 8.8MB/s
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.95

# %% [markdown]
# # Evn

# %%
import os
import random
import shutil
import json
import zipfile
import math
import copy
import collections
import re

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import sentencepiece as spm
import tensorflow as tf
import tensorflow.keras.backend as KK

from tqdm.notebook import tqdm

# %%
# random seed initialize
random_seed = 1234
random.seed(random_seed)
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# %%
# !nvidia-smi
# Out:
# Mon Feb  8 03:54:22 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# google drive mount
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# data dir
data_dir = '/content/drive/MyDrive/data'
os.listdir(data_dir)
# Out:
# ['ko_32000.model', 'ko_32000.vocab', 'kowiki', 'nsmc', 'quora', 'songys']

# %%
# songys chatbot dir
songys_dir = os.path.join(data_dir, 'songys')
if not os.path.exists(songys_dir):
    os.makedirs(songys_dir)
os.listdir(songys_dir)
# Out:
# ['ChatbotData.csv', 'lstm.csv', 'lstm.hdf5', 'lstm_dot.csv', 'lstm_dot.hdf5']

# %% [markdown]
# # Attention

# %%
def get_pad_mask(tokens, i_pad=0):
    """
    pad mask 계산하는 함수
    :param tokens: tokens (bs, n_seq)
    :param i_pad: id of pad
    :return mask: pad mask (pad: 1, other: 0)
    """
    # 0인 부분 확인
    mask = tf.math.equal(tokens, i_pad)
    # boolean -> float 32
    mask = tf.cast(mask, tf.float32)
    # expand dimension for n_seq
    mask = tf.expand_dims(mask, axis=1)
    return mask

# %%
class ScaleDotProductAttention(tf.keras.layers.Layer):
    """
    Scale Dot Product Attention Class
    """
    def __init__(self, name="scale_dot_product_attention"):
        """
        생성자
        :param name: layer name
        """
        super().__init__(name=name)

    def call(self, inputs):
        """
        layer 실행
        :param inputs: Q, K, V, attn_mask tuple
        :return attn_out: attention 실행 결과
        """
        Q, K, V, attn_mask = inputs
        # matmul Q, K (transpose_b=True)
        attn_score = tf.matmul(Q, K, transpose_b=True)
        # get scale = d_model ** 0.5
        scale = tf.math.sqrt(tf.cast(tf.shape(K)[-1], tf.float32))
        # divide by scale
        attn_scale = tf.math.divide(attn_score, scale)
        # do mask (subtract 1e-9 for masked value)
        attn_scale -= 1.e9 * attn_mask
        # calculate attention prob
        attn_prob = tf.nn.softmax(attn_scale, axis=-1)
        # weighted sum of V
        attn_out = tf.matmul(attn_prob, V)
        return attn_out

# %% [markdown]
# # Vocabulary & config

# %%
# vocab loading
vocab = spm.SentencePieceProcessor()
vocab.load(os.path.join(data_dir, 'ko_32000.model'))
# Out:
# True

# %%
n_vocab = len(vocab)  # number of vocabulary
n_enc_seq = 32  # number of sequence 1
n_dec_seq = 40  # number of sequence 2
d_model = 256  # dimension of model

# %% [markdown]
# # 모델링

# %%
def build_model(n_vocab, d_model, n_enc_seq, n_dec_seq):
    """
    문장 유사도 비교 모델
    :param n_vocab: vocabulary 단어 수
    :param d_model: 단어를 의미하는 벡터의 차원 수
    :param n_enc_seq: encoder 문장 길이 (단어 수)
    :param n_dec_seq: decoder 문장 길이 (단어 수)
    """
    inputs_enc = tf.keras.layers.Input((n_enc_seq,))  # (bs, n_enc_seq)
    inputs_dec = tf.keras.layers.Input((n_dec_seq,))  # (bs, n_dec_seq)
    # pad mask 생성
    ###############################################
    enc_dec_mask = get_pad_mask(inputs_enc)
    ###############################################
    # 입력 단어를 vector로 변환
    embedding = tf.keras.layers.Embedding(n_vocab, d_model)
    hidden_enc = embedding(inputs_enc)  # (bs, n_enc_seq, d_model)
    hidden_dec = embedding(inputs_dec)  # (bs, n_dec_seq, d_model)
    # encoder LSTM
    fw_cell = tf.keras.layers.LSTM(units=d_model, return_sequences=True, return_state=True)
    bw_cell = tf.keras.layers.LSTM(units=d_model, go_backwards=True, return_sequences=True, return_state=True)
    lstm_enc = tf.keras.layers.Bidirectional(fw_cell, backward_layer=bw_cell)
    hidden_enc, fw_h, fw_c, bw_h, bw_c = lstm_enc(hidden_enc)  # (bs, n_enc_seq, d_model * 2), (bs, d_model), (bs, d_model), (bs, d_model), (bs, d_model)
    # concat hidden & cell
    s_h = tf.concat([fw_h, bw_h], axis=-1)  # (bs, d_model * 2)
    s_c = tf.concat([fw_c, bw_c], axis=-1)  # (bs, d_model * 2)
    # decoder LSTM
    lstm_dec = tf.keras.layers.LSTM(units=d_model * 2, return_sequences=True)
    hidden_dec = lstm_dec(hidden_dec, initial_state=[s_h, s_c])  # (bs, n_dec_seq, d_model)
    # ScaleDotProductAttention 실행
    ##############################################
    attention = ScaleDotProductAttention()
    attn_out = attention((hidden_dec, hidden_enc, hidden_enc, enc_dec_mask))
    ##############################################
    # concat output
    dec_out = tf.concat([attn_out, hidden_dec], axis=-1)
    # 다음단어 예측
    dense_out = tf.keras.layers.Dense(units=n_vocab, activation=tf.nn.softmax)
    outputs = dense_out(dec_out)  # (bs, n_dec_seq, n_vocab)
    # 학습할 모델 선언
    model = tf.keras.Model(inputs=(inputs_enc, inputs_dec), outputs=outputs)
    return model

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %% [markdown]
# # Loss & Acc

# %%
def lm_loss(y_true, y_pred):
    """
    pad 부분을 제외하고 loss를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 loss 값
    """
    # loss = sparse_entropy = tf.keras.losses.SparseCategoricalCrossentropy()(y_true, y_pred)
    loss = tf.keras.losses.SparseCategoricalCrossentropy(reduction=tf.keras.losses.Reduction.NONE)(y_true, y_pred)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    loss *= mask
    return loss

# %%
def lm_acc(y_true, y_pred):
    """
    pad 부분을 제외하고 accuracy를 계산하는 함수
    :param y_true: 정답
    :param y_pred: 예측 값
    :retrun loss: pad 부분이 제외된 accuracy 값
    """
    y_true = tf.cast(y_true, tf.float32)
    # print(y_true)
    y_pred_class = tf.cast(tf.argmax(y_pred, axis=-1), tf.float32)
    # print(y_pred_class)
    matches = tf.cast(tf.equal(y_true, y_pred_class), tf.float32)
    # print(matches)
    mask = tf.not_equal(y_true, 0)
    mask = tf.cast(mask, tf.float32)
    # print(mask)
    matches *= mask
    # print(matches)
    # accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(tf.ones_like(matches)), 1)
    accuracy = tf.reduce_sum(matches) / tf.maximum(tf.reduce_sum(mask), 1)
    return accuracy

# %% [markdown]
# # All Data Project

# %% [markdown]
# ## Data

# %%
df_train = pd.read_csv(os.path.join(songys_dir, 'ChatbotData.csv'))
print(len(df_train))
df_train = df_train.dropna()
print(len(df_train))
df_train
# Out:
# 11823
# 11823
#                              Q                         A  label
# 0                       12시 땡!                하루가 또 가네요.      0
# 1                  1지망 학교 떨어졌어                 위로해 드립니다.      0
# 2                 3박4일 놀러가고 싶다               여행은 언제나 좋죠.      0
# 3              3박4일 정도 놀러가고 싶다               여행은 언제나 좋죠.      0
# 4                      PPL 심하네                눈살이 찌푸려지죠.      0
# ...                        ...                       ...    ...
# 11818           훔쳐보는 것도 눈치 보임.        티가 나니까 눈치가 보이는 거죠!      2
# 11819           훔쳐보는 것도 눈치 보임.             훔쳐보는 거 티나나봐요.      2
# 11820              흑기사 해주는 짝남.                    설렜겠어요.      2
# 11821  힘든 연애 좋은 연애라는게 무슨 차이일까?  잘 헤어질 수 있는 사이 여부인 거 같아요.      2
# 11822               힘들어서 결혼할까봐        도피성 결혼은 하지 않길 바라요.      2
#
# [11823 rows x 3 columns]

# %%
def load_data(df, n_enc_seq, n_dec_seq):
    """
    Quora 학습 데이터 생성
    :param df: data frame
    :param n_enc_seq: number of encoder sequence
    :param n_dec_seq: number of decoder sequence
    :return enc_inputs: encoder input data
    :return dec_inputs: decoder input data
    :return labels: label data
    """
    n_enc_max = n_enc_seq
    n_dec_max = n_dec_seq - 1
    enc_inputs = np.zeros((len(df), n_enc_seq)).astype(np.int32)
    dec_inputs = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    labels = np.zeros((len(df), n_dec_seq)).astype(np.int32)
    index = 0
    for i, row in tqdm(df.iterrows(), total=len(df)):
        # tokens 저장
        Q = row['Q']
        A = row['A']

        tokens_q = vocab.encode_as_pieces(Q)
        tokens_a = vocab.encode_as_pieces(A)

        tokens_ids_q = vocab.encode_as_ids(Q)[:n_enc_max]
        tokens_ids_a = vocab.encode_as_ids(A)[:n_dec_max]

        tokens_dec_in = [vocab.bos_id()] + tokens_ids_a
        tokens_dec_out = tokens_ids_a + [vocab.eos_id()]

        tokens_ids_q += [0] * (n_enc_seq - len(tokens_ids_q))
        tokens_dec_in += [0] * (n_dec_seq - len(tokens_dec_in))
        tokens_dec_out += [0] * (n_dec_seq - len(tokens_dec_out))

        enc_inputs[index] = tokens_ids_q
        dec_inputs[index] = tokens_dec_in
        labels[index] = tokens_dec_out
        index += 1
    return enc_inputs, dec_inputs, labels

# %%
# train data 생성
train_enc_inputs, train_dec_inputs, train_labels = load_data(df_train, n_enc_seq, n_dec_seq)
train_enc_inputs, train_dec_inputs, train_labels
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11823.0), HTML(value='')))
# (array([[   89,    56,    10, ...,     0,     0,     0],
#         [   35,    47,  1004, ...,     0,     0,     0],
#         [   38,   819,   362, ...,     0,     0,     0],
#         ...,
#         [ 2886,  9525, 21930, ...,     0,     0,     0],
#         [10736,  8256,  1172, ...,     0,     0,     0],
#         [26128,    70,  1381, ...,     0,     0,     0]], dtype=int32),
#  array([[    2,  2261,    19, ...,     0,     0,     0],
#         [    2,  4594,    61, ...,     0,     0,     0],
#         [    2,  2350,    18, ...,     0,     0,     0],
#         ...,
#         [    2,  1522,     1, ...,     0,     0,     0],
#         [    2,   441, 10316, ...,     0,     0,     0],
#         [    2, 16665,    90, ...,     0,     0,     0]], dtype=int32),
#  array([[ 2261,    19,   375, ...,     0,     0,     0],
#         [ 4594,    61,   929, ...,     0,     0,     0],
#         [ 2350,    18,  9001, ...,     0,     0,     0],
#         ...,
#         [ 1522,     1, 12273, ...,     0,     0,     0],
#         [  441, 10316,   515, ...,     0,     0,     0],
#         [16665,    90,  1381, ...,     0,     0,     0]], dtype=int32))

# %% [markdown]
# ## 학습

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# 모델 내용 그래프 출력
tf.keras.utils.plot_model(model, 'model.png', show_shapes=True)

# %%
# 모델 loss, optimizer, metric 정의
model.compile(loss=lm_loss, optimizer='adam', metrics=[lm_acc])

# %%
# early stopping
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='lm_acc', patience=5)
# save weights callback
save_weights = tf.keras.callbacks.ModelCheckpoint(os.path.join(songys_dir, 'lstm_scale_dot.hdf5'),
                                                  monitor='lm_acc',
                                                  verbose=1,
                                                  save_best_only=True,
                                                  mode="max",
                                                  save_freq="epoch",
                                                  save_weights_only=True)
# csv logger
csv_logger = tf.keras.callbacks.CSVLogger(os.path.join(songys_dir, 'lstm_scale_dot.csv'))

# %%
# 모델 학습
history = model.fit((train_enc_inputs, train_dec_inputs),
                    train_labels,
                    epochs=100,
                    batch_size=256,
                    callbacks=[early_stopping, save_weights, csv_logger])
# Out:
# Epoch 1/100
# 47/47 [==============================] - 48s 800ms/step - loss: 1.8896 - lm_acc: 0.1111
#
# Epoch 00001: lm_acc improved from -inf to 0.11861, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 2/100
# 47/47 [==============================] - 40s 849ms/step - loss: 1.2906 - lm_acc: 0.1456
#
# Epoch 00002: lm_acc improved from 0.11861 to 0.16854, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 3/100
# 47/47 [==============================] - 39s 837ms/step - loss: 1.1755 - lm_acc: 0.2516
#
# Epoch 00003: lm_acc improved from 0.16854 to 0.26894, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 4/100
# 47/47 [==============================] - 40s 845ms/step - loss: 1.0884 - lm_acc: 0.2924
#
# Epoch 00004: lm_acc improved from 0.26894 to 0.29967, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 5/100
# 47/47 [==============================] - 40s 845ms/step - loss: 1.0280 - lm_acc: 0.3267
#
# Epoch 00005: lm_acc improved from 0.29967 to 0.33496, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 6/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.9694 - lm_acc: 0.3545
#
# Epoch 00006: lm_acc improved from 0.33496 to 0.35763, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 7/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.9222 - lm_acc: 0.3721
#
# Epoch 00007: lm_acc improved from 0.35763 to 0.37782, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 8/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.8723 - lm_acc: 0.3915
#
# Epoch 00008: lm_acc improved from 0.37782 to 0.39490, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 9/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.8297 - lm_acc: 0.4061
#
# Epoch 00009: lm_acc improved from 0.39490 to 0.40817, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 10/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.7933 - lm_acc: 0.4194
#
# Epoch 00010: lm_acc improved from 0.40817 to 0.42046, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 11/100
# 47/47 [==============================] - 40s 852ms/step - loss: 0.7550 - lm_acc: 0.4351
#
# Epoch 00011: lm_acc improved from 0.42046 to 0.43496, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 12/100
# 47/47 [==============================] - 39s 839ms/step - loss: 0.7170 - lm_acc: 0.4480
#
# Epoch 00012: lm_acc improved from 0.43496 to 0.44823, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 13/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.6823 - lm_acc: 0.4627
#
# Epoch 00013: lm_acc improved from 0.44823 to 0.46192, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 14/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.6526 - lm_acc: 0.4764
#
# Epoch 00014: lm_acc improved from 0.46192 to 0.47823, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 15/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.6156 - lm_acc: 0.4971
#
# Epoch 00015: lm_acc improved from 0.47823 to 0.49668, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 16/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.5775 - lm_acc: 0.5196
#
# Epoch 00016: lm_acc improved from 0.49668 to 0.51570, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 17/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.5515 - lm_acc: 0.5360
#
# Epoch 00017: lm_acc improved from 0.51570 to 0.53486, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 18/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.5200 - lm_acc: 0.5561
#
# Epoch 00018: lm_acc improved from 0.53486 to 0.55411, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 19/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.4924 - lm_acc: 0.5798
#
# Epoch 00019: lm_acc improved from 0.55411 to 0.57543, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 20/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.4611 - lm_acc: 0.5996
#
# Epoch 00020: lm_acc improved from 0.57543 to 0.59513, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 21/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.4365 - lm_acc: 0.6192
#
# Epoch 00021: lm_acc improved from 0.59513 to 0.61414, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 22/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.4135 - lm_acc: 0.6360
#
# Epoch 00022: lm_acc improved from 0.61414 to 0.63111, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 23/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.3951 - lm_acc: 0.6522
#
# Epoch 00023: lm_acc improved from 0.63111 to 0.64980, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 24/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.3695 - lm_acc: 0.6714
#
# Epoch 00024: lm_acc improved from 0.64980 to 0.66699, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 25/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.3543 - lm_acc: 0.6850
#
# Epoch 00025: lm_acc improved from 0.66699 to 0.68479, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 26/100
# 47/47 [==============================] - 39s 840ms/step - loss: 0.3321 - lm_acc: 0.7047
#
# Epoch 00026: lm_acc improved from 0.68479 to 0.70099, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 27/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.3120 - lm_acc: 0.7239
#
# Epoch 00027: lm_acc improved from 0.70099 to 0.71660, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 28/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2960 - lm_acc: 0.7375
#
# Epoch 00028: lm_acc improved from 0.71660 to 0.73321, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 29/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2819 - lm_acc: 0.7499
#
# Epoch 00029: lm_acc improved from 0.73321 to 0.74741, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 30/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2681 - lm_acc: 0.7631
#
# Epoch 00030: lm_acc improved from 0.74741 to 0.75991, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 31/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.2538 - lm_acc: 0.7768
#
# Epoch 00031: lm_acc improved from 0.75991 to 0.77492, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 32/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.2358 - lm_acc: 0.7927
#
# Epoch 00032: lm_acc improved from 0.77492 to 0.78915, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 33/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.2255 - lm_acc: 0.8022
#
# Epoch 00033: lm_acc improved from 0.78915 to 0.79954, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 34/100
# 47/47 [==============================] - 40s 841ms/step - loss: 0.2119 - lm_acc: 0.8160
#
# Epoch 00034: lm_acc improved from 0.79954 to 0.81211, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 35/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.2004 - lm_acc: 0.8270
#
# Epoch 00035: lm_acc improved from 0.81211 to 0.82321, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 36/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.1880 - lm_acc: 0.8402
#
# Epoch 00036: lm_acc improved from 0.82321 to 0.83642, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 37/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.1760 - lm_acc: 0.8508
#
# Epoch 00037: lm_acc improved from 0.83642 to 0.84774, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 38/100
# 47/47 [==============================] - 40s 840ms/step - loss: 0.1672 - lm_acc: 0.8620
#
# Epoch 00038: lm_acc improved from 0.84774 to 0.85741, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 39/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.1577 - lm_acc: 0.8697
#
# Epoch 00039: lm_acc improved from 0.85741 to 0.86544, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 40/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.1509 - lm_acc: 0.8779
#
# Epoch 00040: lm_acc improved from 0.86544 to 0.86985, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 41/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.1436 - lm_acc: 0.8849
#
# Epoch 00041: lm_acc improved from 0.86985 to 0.87782, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 42/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.1370 - lm_acc: 0.8894
#
# Epoch 00042: lm_acc improved from 0.87782 to 0.88848, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 43/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.1255 - lm_acc: 0.9018
#
# Epoch 00043: lm_acc improved from 0.88848 to 0.89965, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 44/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.1150 - lm_acc: 0.9120
#
# Epoch 00044: lm_acc improved from 0.89965 to 0.90777, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 45/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.1085 - lm_acc: 0.9191
#
# Epoch 00045: lm_acc improved from 0.90777 to 0.91675, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 46/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.1006 - lm_acc: 0.9268
#
# Epoch 00046: lm_acc improved from 0.91675 to 0.92499, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 47/100
# 47/47 [==============================] - 39s 840ms/step - loss: 0.0942 - lm_acc: 0.9335
#
# Epoch 00047: lm_acc improved from 0.92499 to 0.93059, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 48/100
# 47/47 [==============================] - 40s 847ms/step - loss: 0.0902 - lm_acc: 0.9376
#
# Epoch 00048: lm_acc improved from 0.93059 to 0.93590, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 49/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0830 - lm_acc: 0.9435
#
# Epoch 00049: lm_acc improved from 0.93590 to 0.94183, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 50/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0776 - lm_acc: 0.9497
#
# Epoch 00050: lm_acc improved from 0.94183 to 0.94746, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 51/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0718 - lm_acc: 0.9553
#
# Epoch 00051: lm_acc improved from 0.94746 to 0.95281, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 52/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0685 - lm_acc: 0.9587
#
# Epoch 00052: lm_acc improved from 0.95281 to 0.95816, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 53/100
# 47/47 [==============================] - 40s 847ms/step - loss: 0.0643 - lm_acc: 0.9633
#
# Epoch 00053: lm_acc improved from 0.95816 to 0.96104, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 54/100
# 47/47 [==============================] - 40s 841ms/step - loss: 0.0599 - lm_acc: 0.9654
#
# Epoch 00054: lm_acc improved from 0.96104 to 0.96353, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 55/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.0558 - lm_acc: 0.9701
#
# Epoch 00055: lm_acc improved from 0.96353 to 0.96861, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 56/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.0520 - lm_acc: 0.9735
#
# Epoch 00056: lm_acc improved from 0.96861 to 0.97189, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 57/100
# 47/47 [==============================] - 40s 847ms/step - loss: 0.0474 - lm_acc: 0.9765
#
# Epoch 00057: lm_acc improved from 0.97189 to 0.97492, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 58/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0471 - lm_acc: 0.9773
#
# Epoch 00058: lm_acc improved from 0.97492 to 0.97674, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 59/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0431 - lm_acc: 0.9804
#
# Epoch 00059: lm_acc improved from 0.97674 to 0.97901, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 60/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0423 - lm_acc: 0.9802
#
# Epoch 00060: lm_acc did not improve from 0.97901
# Epoch 61/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0447 - lm_acc: 0.9773
#
# Epoch 00061: lm_acc did not improve from 0.97901
# Epoch 62/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0383 - lm_acc: 0.9836
#
# Epoch 00062: lm_acc improved from 0.97901 to 0.98322, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 63/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0332 - lm_acc: 0.9876
#
# Epoch 00063: lm_acc improved from 0.98322 to 0.98647, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 64/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.0319 - lm_acc: 0.9876
#
# Epoch 00064: lm_acc improved from 0.98647 to 0.98760, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 65/100
# 47/47 [==============================] - 39s 839ms/step - loss: 0.0288 - lm_acc: 0.9905
#
# Epoch 00065: lm_acc improved from 0.98760 to 0.98942, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 66/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0272 - lm_acc: 0.9914
#
# Epoch 00066: lm_acc improved from 0.98942 to 0.99096, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 67/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0248 - lm_acc: 0.9927
#
# Epoch 00067: lm_acc improved from 0.99096 to 0.99236, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 68/100
# 47/47 [==============================] - 39s 840ms/step - loss: 0.0230 - lm_acc: 0.9940
#
# Epoch 00068: lm_acc improved from 0.99236 to 0.99374, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 69/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0209 - lm_acc: 0.9950
#
# Epoch 00069: lm_acc improved from 0.99374 to 0.99453, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 70/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0211 - lm_acc: 0.9950
#
# Epoch 00070: lm_acc improved from 0.99453 to 0.99494, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 71/100
# 47/47 [==============================] - 40s 847ms/step - loss: 0.0202 - lm_acc: 0.9947
#
# Epoch 00071: lm_acc did not improve from 0.99494
# Epoch 72/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.0212 - lm_acc: 0.9944
#
# Epoch 00072: lm_acc did not improve from 0.99494
# Epoch 73/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0186 - lm_acc: 0.9954
#
# Epoch 00073: lm_acc improved from 0.99494 to 0.99547, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 74/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0167 - lm_acc: 0.9965
#
# Epoch 00074: lm_acc improved from 0.99547 to 0.99635, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 75/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0150 - lm_acc: 0.9971
#
# Epoch 00075: lm_acc improved from 0.99635 to 0.99675, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 76/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0151 - lm_acc: 0.9972
#
# Epoch 00076: lm_acc improved from 0.99675 to 0.99697, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 77/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.0133 - lm_acc: 0.9976
#
# Epoch 00077: lm_acc improved from 0.99697 to 0.99716, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 78/100
# 47/47 [==============================] - 40s 849ms/step - loss: 0.0125 - lm_acc: 0.9980
#
# Epoch 00078: lm_acc improved from 0.99716 to 0.99784, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 79/100
# 47/47 [==============================] - 40s 848ms/step - loss: 0.0115 - lm_acc: 0.9982
#
# Epoch 00079: lm_acc did not improve from 0.99784
# Epoch 80/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0107 - lm_acc: 0.9985
#
# Epoch 00080: lm_acc improved from 0.99784 to 0.99815, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 81/100
# 47/47 [==============================] - 40s 847ms/step - loss: 0.0100 - lm_acc: 0.9984
#
# Epoch 00081: lm_acc improved from 0.99815 to 0.99827, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 82/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0094 - lm_acc: 0.9989
#
# Epoch 00082: lm_acc improved from 0.99827 to 0.99838, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 83/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0096 - lm_acc: 0.9984
#
# Epoch 00083: lm_acc did not improve from 0.99838
# Epoch 84/100
# 47/47 [==============================] - 40s 844ms/step - loss: 0.0088 - lm_acc: 0.9985
#
# Epoch 00084: lm_acc improved from 0.99838 to 0.99840, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 85/100
# 47/47 [==============================] - 40s 848ms/step - loss: 0.0081 - lm_acc: 0.9988
#
# Epoch 00085: lm_acc improved from 0.99840 to 0.99851, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 86/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.0078 - lm_acc: 0.9987
#
# Epoch 00086: lm_acc improved from 0.99851 to 0.99861, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 87/100
# 47/47 [==============================] - 40s 847ms/step - loss: 0.0072 - lm_acc: 0.9989
#
# Epoch 00087: lm_acc improved from 0.99861 to 0.99865, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 88/100
# 47/47 [==============================] - 40s 845ms/step - loss: 0.0072 - lm_acc: 0.9989
#
# Epoch 00088: lm_acc improved from 0.99865 to 0.99873, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 89/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.0066 - lm_acc: 0.9989
#
# Epoch 00089: lm_acc improved from 0.99873 to 0.99876, saving model to /content/drive/MyDrive/data/songys/lstm_scale_dot.hdf5
# Epoch 90/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0064 - lm_acc: 0.9988
#
# Epoch 00090: lm_acc did not improve from 0.99876
# Epoch 91/100
# 47/47 [==============================] - 40s 843ms/step - loss: 0.0065 - lm_acc: 0.9989
#
# Epoch 00091: lm_acc did not improve from 0.99876
# Epoch 92/100
# 47/47 [==============================] - 40s 846ms/step - loss: 0.0063 - lm_acc: 0.9988
#
# Epoch 00092: lm_acc did not improve from 0.99876
# Epoch 93/100
# 47/47 [==============================] - 40s 847ms/step - loss: 0.0062 - lm_acc: 0.9988
#
# Epoch 00093: lm_acc did not improve from 0.99876
# Epoch 94/100
# 47/47 [==============================] - 40s 842ms/step - loss: 0.0057 - lm_acc: 0.9989
#
# Epoch 00094: lm_acc did not improve from 0.99876

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'b-', label='loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['lm_acc'], 'g-', label='acc')
plt.xlabel('Epoch')
plt.legend()

plt.show()

# %% [markdown]
# ## Inference

# %%
# 모델 생성
model = build_model(len(vocab), d_model, n_enc_seq, n_dec_seq)
# train weight로 초기화
model.load_weights(os.path.join(songys_dir, 'lstm_scale_dot.hdf5'))

# %%
def do_chat(vocab, model, n_enc_seq, n_dec_seq, string):
    """
    seq2seq chat
    :param vocab: vocab
    :param model: model
    :param n_enc_seq: number of enc seqence
    :param n_dec_seq: number of dec seqence
    :param string: inpust string
    """
    # qeustion
    q = vocab.encode_as_pieces(string)
    q_id = [vocab.piece_to_id(p) for p in q][:n_enc_seq]
    q_id += [0] * (n_enc_seq - len(q_id))
    assert len(q_id) == n_enc_seq

    # answer
    a_id = [vocab.bos_id()]
    a_id += [0] * (n_dec_seq - len(a_id))
    assert len(a_id) == n_dec_seq

    # 처음부터 예측
    start_idx = 0

    for _ in range(start_idx, n_dec_seq - 1):
        outputs = model.predict((np.array([q_id]), np.array([a_id])))
        prob = outputs[0][start_idx]
        word_id = np.argmax(prob)
        if word_id == vocab.eos_id():
            break
        a_id[start_idx + 1] = int(word_id)
        start_idx += 1
    predict_id = a_id[1:start_idx + 1]
    predict_str = vocab.decode_ids(predict_id)
    return predict_str

# %%
while True:
    string = input('질문 > ')
    string = string.strip()
    if len(string) == 0:
        break
    predict_str = do_chat(vocab, model, n_enc_seq, n_dec_seq, string)
    print(f'답변 > {predict_str}')
# Out:
# 질문 > 안녕
# 답변 > 안녕하세요.
# 질문 > 너는 누구야
# 답변 > 저는 위로해드리는 로봇이에요.
# 질문 > 나는 누구일까
# 답변 > 저는 마음을 이어주는 위로봇입니다.
# 질문 > 지금 뭐해
# 답변 > 아직 뭐든 좋죠.
# 질문 > 오늘 너무 바빠
# 답변 > 조심하세요.
# 질문 > 뭐할까
# 답변 > 오늘은 예능이요.
# 질문 > 무엇을 좋아하니
# 답변 > 먼저 연락해보세요.
# 질문 > 싫어하는 것은
# 답변 > 자신이 있으면 저.
# 질문 > 졸려
# 답변 > 오늘 일찍 주무세요.
# 질문 > 힘들어
# 답변 > 지금은 힘들겠지만 조금만 더 견뎌봐요.
# 질문 > 재미있어
# 답변 > 색감에는 언제나 좋죠.
# 질문 > 즐거워
# 답변 > 저는 항상 고민이죠.
# 질문 > 언제 가
# 답변 > 오늘도 좋은것이예요.
# 질문 > 그만 갈게
# 답변 > 소소한 차를 좋아요.
# 질문 > 잘 있어
# 답변 > 잘자요.
# 질문 >
